# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import numpy as np

def complex_function(x):
    return np.sin(x) + 0.2 * x + np.random.normal(0, 0.1, x.shape)

x_data = np.linspace(-5, 5, 1000).reshape(-1, 1)
y_data = complex_function(x_data)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

model = Sequential([
    Dense(32, activation='relu', input_shape=(1,)),
    Dense(64, activation='relu'),
    Dense(1)])
model.compile(optimizer=Adam(), loss='mean_squared_error')
model.fit(x_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
predictions = model.predict(x_test)

import matplotlib.pyplot as plt
plt.scatter(x_test, y_test, label='True Data')
plt.scatter(x_test, predictions, label='Predictions')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 20/20 [==============================] - 1s 10ms/step - loss: 0.5925 - val_loss: 0.4421
# Epoch 2/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4572 - val_loss: 0.3707
# Epoch 3/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4042 - val_loss: 0.3342
# Epoch 4/20
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3605 - val_loss: 0.3065
# Epoch 5/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3167 - val_loss: 0.2563
# Epoch 6/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2639 - val_loss: 0.2329
# Epoch 7/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2248 - val_loss: 0.1798
# Epoch 8/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1723 - val_loss: 0.1384
# Epoch 9/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1254 - val_loss: 0.1001
# Epoch 10/20
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0880 - val_loss: 0.0728
# Epoch 11/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0629 - val_loss: 0.0501
# Epoch 12/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0472 - val_loss: 0.0434
# Epoch 13/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0356 - val_loss: 0.0296
# Epoch 14/20
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.0242
# Epoch 15/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0262 - val_loss: 0.0224
# Epoch 16/20
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0241 - val_loss: 0.0210
# Epoch 17/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0215 - val_loss: 0.0206
# Epoch 18/20
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0216 - val_loss: 0.0217
# Epoch 19/20
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0215 - val_loss: 0.0200
# Epoch 20/20
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.0222
# 7/7 [==============================] - 0s 2ms/step
